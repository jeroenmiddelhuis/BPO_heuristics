# %%
import numpy as np
from sb3_contrib import MaskablePPO
from simulator import Simulator
from gym_env import Environment
from heuristics import random_policy
import torch

config_type = "high_utilization"  # Change this to "low_utilization" or "high_utilization" as needed

# Load the trained PPO model
model_path = f"models/PPO/{config_type}/{config_type}_best.zip"
model = MaskablePPO.load(model_path)

# Create the environment (matching the training config)
simulator = Simulator(config_type=config_type, nr_cases=1000)
env = Environment(simulator)

random_states = []

step_count = 0
while len(random_states) < 100:
    done = False
    obs = env.reset()
    while not done:
        action = random_policy(simulator)
        obs, reward, done, _, _ = env.step(action)
        step_count += 1
        if step_count % 100 == 0:
            random_states.append(obs.copy())

print(random_states)


actions = {0: "spt_policy",
          1: "fifo_policy",
          2: "shortest_queue_policy",
          3: "longest_queue_policy",
          4: "postpone"}
track_actions = {0:0,
                  1:0,
                  2:0,
                  3:0,
                  4:0}

# Predict actions and print probabilities for each random state
for i, obs in enumerate(random_states):
    # Convert observation to the correct shape and type
    obs_tensor = torch.as_tensor(obs, dtype=torch.float32).unsqueeze(0)
    # Get action mask for this state
    mask = env.action_masks()
    mask_tensor = torch.as_tensor(mask, dtype=torch.bool).unsqueeze(0)
    # Get action probabilities from the policy
    with torch.no_grad():
        dist = model.policy.get_distribution(obs_tensor)
        probs = dist.distribution.probs.cpu().numpy().flatten()
    action = np.argmax(probs)
    track_actions[int(action)] += 1
    print(f"Sample {i+1}:")
    print("Observation:", obs)
    print("Predicted action:", action)
    print("Probabilities:", probs)
    print("-" * 40)
print("Action counts:", track_actions)
# Out:
# Episode 0 completed. Action counts: {'spt_policy': 0, 'fifo_policy': 0, 'shortest_queue_policy': 0, 'longest_queue_policy': 0, 'postpone': 0}
# Total reward: 0. Total cycle time: 0
# Episode 1 completed. Action counts: {'spt_policy': 0, 'fifo_policy': 0, 'shortest_queue_policy': 0, 'longest_queue_policy': 0, 'postpone': 0}
# Total reward: 106.0719781770076. Total cycle time: 17976.371858905204
# Episode 2 completed. Action counts: {'spt_policy': 0, 'fifo_policy': 0, 'shortest_queue_policy': 0, 'longest_queue_policy': 0, 'postpone': 0}
# Total reward: 121.94777379255936. Total cycle time: 14264.943788374632
# Episode 3 completed. Action counts: {'spt_policy': 0, 'fifo_policy': 0, 'shortest_queue_policy': 0, 'longest_queue_policy': 0, 'postpone': 0}
# Total reward: 59.160138906912024. Total cycle time: 31901.13089756142
# Episode 4 completed. Action counts: {'spt_policy': 0, 'fifo_policy': 0, 'shortest_queue_policy': 0, 'longest_queue_policy': 0, 'postpone': 0}
# Total reward: 68.52315850221399. Total cycle time: 26247.741617410626
# [array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.  ]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.  ]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.07, 0.03]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.  ]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.04, 0.02]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.19, 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.19, 0.06]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.15]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.03]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.02]), array([0. , 1. , 0. , 0. , 0. , 0. , 0.1, 0. ]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.12, 0.04]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.02]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.05]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.08, 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.03, 0.04]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.02, 0.03]), array([1., 1., 0., 0., 0., 0., 0., 0.]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.07, 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.04, 0.01]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.02, 0.  ]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.05, 0.  ]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.04, 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.05, 0.  ]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.08, 0.  ]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.05, 0.03]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.06, 0.07]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.02]), array([1.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.  ]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.02, 0.  ]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.05, 0.03]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.04]), array([1.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.  ]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.12]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.12, 0.  ]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.1 , 0.04]), array([1., 1., 0., 0., 0., 0., 0., 0.]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.17, 0.02]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.03, 0.08]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.06]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.01, 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.03]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.07, 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.1 , 0.03]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.1 , 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.05, 0.02]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.06, 0.04]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.07, 0.01]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.08, 0.03]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.05, 0.1 ]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.17, 0.19]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.22, 0.03]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.11, 0.15]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.11, 0.19]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.21, 0.14]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.02, 0.2 ]), array([1., 1., 0., 0., 0., 0., 0., 0.]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.15, 0.05]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.08, 0.04]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.06, 0.09]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.01]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.01]), array([1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.14, 0.03]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.17, 0.12]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.17, 0.01]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.05, 0.02]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.14, 0.02]), array([0.  , 1.  , 0.  , 0.  , 0.  , 0.  , 0.  , 0.03]), array([1 ...
# Sample 1:
# Observation: [0.   1.   0.   0.   0.   0.   0.01 0.  ]
# Predicted action: 3
# Probabilities: [0.04435084 0.2467173  0.14257    0.40572453 0.16063727]
# ----------------------------------------
# Sample 2:
# Observation: [1.   0.   0.   0.   0.   0.   0.01 0.  ]
# Predicted action: 3
# Probabilities: [0.02527281 0.05771145 0.13996531 0.6665158  0.11053458]
# ----------------------------------------
# Sample 3:
# Observation: [0.   1.   0.   0.   0.   0.   0.07 0.03]
# Predicted action: 3
# Probabilities: [0.04458033 0.248617   0.1435036  0.40233278 0.16096637]
# ----------------------------------------
# Sample 4:
# Observation: [1.   0.   0.   0.   0.   0.   0.01 0.  ]
# Predicted action: 3
# Probabilities: [0.02527281 0.05771145 0.13996531 0.6665158  0.11053458]
# ----------------------------------------
# Sample 5:
# Observation: [0.   1.   0.   0.   0.   0.   0.   0.01]
# Predicted action: 3
# Probabilities: [0.04427449 0.24658374 0.1423907  0.4061872  0.16056392]
# ----------------------------------------
# Sample 6:
# Observation: [1.   0.   0.   0.   0.   0.   0.04 0.02]
# Predicted action: 3
# Probabilities: [0.02530586 0.05795307 0.1405342  0.66548705 0.11071976]
# ----------------------------------------
# Sample 7:
# Observation: [1.   0.   0.   0.   0.   0.   0.19 0.01]
# Predicted action: 3
# Probabilities: [0.02578663 0.05905713 0.1438125  0.65939456 0.11194921]
# ----------------------------------------
# Sample 8:
# Observation: [1.   0.   0.   0.   0.   0.   0.19 0.06]
# Predicted action: 3
# Probabilities: [0.02569761 0.05918989 0.1437389  0.6594611  0.11191256]
# ----------------------------------------
# Sample 9:
# Observation: [1.   0.   0.   0.   0.   0.   0.   0.15]
# Predicted action: 3
# Probabilities: [0.02503513 0.05812668 0.1396386  0.6667453  0.1104543 ]
# ----------------------------------------
# Sample 10:
# Observation: [1.   0.   0.   0.   0.   0.   0.01 0.01]
# Predicted action: 3
# Probabilities: [0.02525296 0.05773482 0.13994586 0.6665431  0.11052325]
# ----------------------------------------
# Sample 11:
# Observation: [1.   0.   0.   0.   0.   0.   0.01 0.03]
# Predicted action: 3
# Probabilities: [0.02521561 0.05778519 0.13991164 0.6665825  0.110505  ]
# ----------------------------------------
# Sample 12:
# Observation: [1.   0.   0.   0.   0.   0.   0.01 0.02]
# Predicted action: 3
# Probabilities: [0.02523389 0.0577594  0.13992797 0.66656536 0.11051338]
# ----------------------------------------
# Sample 13:
# Observation: [0.  1.  0.  0.  0.  0.  0.1 0. ]
# Predicted action: 3
# Probabilities: [0.04483247 0.24901009 0.14406462 0.40089065 0.16120215]
# ----------------------------------------
# Sample 14:
# Observation: [1.   0.   0.   0.   0.   0.   0.12 0.04]
# Predicted action: 3
# Probabilities: [0.02549464 0.05857383 0.14219521 0.66242063 0.11131562]
# ----------------------------------------
# Sample 15:
# Observation: [1.   0.   0.   0.   0.   0.   0.   0.02]
# Predicted action: 3
# Probabilities: [0.02521138 0.05769722 0.13972937 0.6669147  0.11044735]
# ----------------------------------------
# Sample 16:
# Observation: [0.   1.   0.   0.   0.   0.   0.   0.05]
# Predicted action: 3
# Probabilities: [0.04417262 0.24706875 0.14232793 0.40591496 0.16051573]
# ----------------------------------------
# Sample 17:
# Observation: [1.   0.   0.   0.   0.   0.   0.08 0.01]
# Predicted action: 3
# Probabilities: [0.02543137 0.05820345 0.14138421 0.66395664 0.11102436]
# ----------------------------------------
# Sample 18:
# Observation: [1.   0.   0.   0.   0.   0.   0.03 0.04]
# Predicted action: 3
# Probabilities: [0.02524534 0.05794002 0.1402994  0.665881   0.11063426]
# ----------------------------------------
# Sample 19:
# Observation: [0.   1.   0.   0.   0.   0.   0.02 0.03]
# Predicted action: 3
# Probabilities: [0.04431847 0.24733815 0.14267904 0.40500787 0.16065644]
# ----------------------------------------
# Sample 20:
# Observation: [1. 1. 0. 0. 0. 0. 0. 0.]
# Predicted action: 3
# Probabilities: [0.00929189 0.06831738 0.09039079 0.7487631  0.08323681]
# ----------------------------------------
# Sample 21:
# Observation: [0.   1.   0.   0.   0.   0.   0.07 0.01]
# Predicted action: 3
# Probabilities: [0.04463375 0.2483702  0.14353782 0.4024657  0.16099253]
# ----------------------------------------
# Sample 22:
# Observation: [1.   0.   0.   0.   0.   0.   0.   0.01]
# Predicted action: 3
# Probabilities: [0.02523045 0.0576726  0.13974729 0.6668924  0.11045723]
# ----------------------------------------
# Sample 23:
# Observation: [1.   0.   0.   0.   0.   0.   0.04 0.01]
# Predicted action: 3
# Probabilities: [0.02532494 0.05792858 0.14055198 0.66546494 0.1107296 ]
# ----------------------------------------
# Sample 24:
# Observation: [0.   1.   0.   0.   0.   0.   0.02 0.  ]
# Predicted action: 3
# Probabilities: [0.04440002 0.24697231 0.14273173 0.40519896 0.160697  ]
# ----------------------------------------
# Sample 25:
# Observation: [0.   1.   0.   0.   0.   0.   0.05 0.  ]
# Predicted action: 3
# Probabilities: [0.04455403 0.2477372  0.14322345 0.40360457 0.16088071]
# ----------------------------------------
# Sample 26:
# Observation: [1.   0.   0.   0.   0.   0.   0.04 0.01]
# Predicted action: 3
# Probabilities: [0.02532494 0.05792858 0.14055198 0.66546494 0.1107296 ]
# ----------------------------------------
# Sample 27:
# Observation: [1.   0.   0.   0.   0.   0.   0.05 0.  ]
# Predicted action: 3
# Probabilities: [0.02537031 0.05797225 0.1407768  0.66506803 0.11081261]
# ----------------------------------------
# Sample 28:
# Observation: [1.   0.   0.   0.   0.   0.   0.08 0.  ]
# Predicted action: 3
# Probabilities: [0.02545128 0.05818025 0.1414034  0.6639292  0.11103576]
# ----------------------------------------
# Sample 29:
# Observation: [1.   0.   0.   0.   0.   0.   0.05 0.03]
# Predicted action: 3
# Probabilities: [0.02531302 0.05804568 0.14072347 0.6651349  0.11078289]
# ----------------------------------------
# Sample 30:
# Observation: [1.   0.   0.   0.   0.   0.   0.06 0.07]
# Predicted action: 3
# Probabilities: [0.02527383 0.05822853 0.14088134 0.6647794  0.1108369 ]
# ----------------------------------------
# Sample 31:
# Observation: [1.   0.   0.   0.   0.   0.   0.   0.02]
# Predicted action: 3
# Probabilities: [0.02521138 0.05769722 0.13972937 0.6669147  0.11044735]
# ----------------------------------------
# Sample 32:
# Observation: [1.   1.   0.   0.   0.   0.   0.01 0.  ]
# Predicted action: 3
# Probabilities: [0.0093036  0.06839601 0.09052736 0.7484714  0.08330166]
# ----------------------------------------
# Sample 33:
# Observation: [1.   0.   0.   0.   0.   0.   0.02 0.  ]
# Predicted action: 3
# Probabilities: [0.02529606 0.05777487 0.14016558 0.6661615  0.11060198]
# ----------------------------------------
# Sample 34:
# Observation: [1.   0.   0.   0.   0.   0.   0.05 0.03]
# Predicted action: 3
# Probabilities: [0.02531302 0.05804568 0.14072347 0.6651349  0.11078289]
# ----------------------------------------
# Sample 35:
# Observation: [1.   0.   0.   0.   0.   0.   0.   0.04]
# Predicted action: 3
# Probabilities: [0.02517562 0.05775003 0.13969818 0.6669441  0.11043211]
# ----------------------------------------
# Sample 36:
# Observation: [1.   1.   0.   0.   0.   0.   0.01 0.  ]
# Predicted action: 3
# Probabilities: [0.0093036  0.06839601 0.09052736 0.7484714  0.08330166]
# ----------------------------------------
# Sample 37:
# Observation: [0.   1.   0.   0.   0.   0.   0.   0.12]
# Predicted action: 3
# Probabilities: [0.04403756 0.24791461 0.14226522 0.40531382 0.1604689 ]
# ----------------------------------------
# Sample 38:
# Observation: [0.   1.   0.   0.   0.   0.   0.12 0.  ]
# Predicted action: 3
# Probabilities: [0.04495142 0.24951807 0.14440848 0.39978617 0.16133589]
# ----------------------------------------
# Sample 39:
# Observation: [1.   0.   0.   0.   0.   0.   0.1  0.04]
# Predicted action: 3
# Probabilities: [0.02543399 0.05842471 0.14176206 0.6632247  0.1111545 ]
# ----------------------------------------
# Sample 40:
# Observation: [1. 1. 0. 0. 0. 0. 0. 0.]
# Predicted action: 3
# Probabilities: [0.00929189 0.06831738 0.09039079 0.7487631  0.08323681]
# ----------------------------------------
# Sample 41:
# Observation: [0.   1.   0.   0.   0.   0.   0.17 0.02]
# Predicted action: 3
# Probabilities: [0.04521137 0.25103584 0.14524838 0.39685017 0.16165414]
# ----------------------------------------
# Sample 42:
# Observation: [1.   0.   0.   0.   0.   0.   0.03 0.08]
# Predicted action: 3
# Probabilities: [0.0251832  0.05805989 0.14025606 0.6658794  0.11062139]
# ----------------------------------------
# Sample 43:
# Observation: [0.   1.   0.   0.   0.   0.   0.   0.06]
# Predicted action: 3
# Probabilities: [0.04414997 0.24718986 0.14231528 0.4058388  0.16050613]
# ----------------------------------------
# Sample 44:
# Observation: [0.   1.   0.   0.   0.   0.   0.01 0.01]
# Predicted action: 3
# Probabilities: [0.04432257 0.246839   0.14255126 0.40566435 0.1606228 ]
# ----------------------------------------
# Sample 45:
# Observation: [1.   0.   0.   0.   0.   0.   0.   0.03]
# Predicted action: 3
# Probabilities: [0.02519311 0.05772302 0.13971299 0.6669319  0.11043898]
# ----------------------------------------
# Sample 46:
# Observation: [1.   0.   0.   0.   0.   0.   0.07 0.01]
# Predicted action: 3
# Probabilities: [0.02540364 0.05813295 0.14117356 0.6643412  0.11094856]
# ----------------------------------------
# Sample 47:
# Observation: [1.   0.   0.   0.   0.   0.   0.1  0.03]
# Predicted action: 3
# Probabilities: [0.02545158 0.05839792 0.14177667 0.66321224 0.11116155]
# ----------------------------------------
# Sample 48:
# Observation: [0.   1.   0.   0.   0.   0.   0.1  0.01]
# Predicted action: 3
# Probabilities: [0.04480399 0.24913447 0.14404562 0.4008284  0.1611876 ]
# ----------------------------------------
# Sample 49:
# Observation: [1.   0.   0.   0.   0.   0.   0.05 0.02]
# Predicted action: 3
# Probabilities: [0.02533133 0.05801999 0.1407397  0.6651177  0.11079131]
# ----------------------------------------
# Sample 50:
# Observation: [1.   0.   0.   0.   0.   0.   0.06 0.04]
# Predicted action: 3
# Probabilities: [0.02532171 0.05814065 0.14091605 0.6647727  0.11084888]
# ----------------------------------------
# Sample 51:
# Observation: [1.   0.   0.   0.   0.   0.   0.07 0.01]
# Predicted action: 3
# Probabilities: [0.02540364 0.05813295 0.14117356 0.6643412  0.11094856]
# ----------------------------------------
# Sample 52:
# Observation: [0.   1.   0.   0.   0.   0.   0.08 0.03]
# Predicted action: 3
# Probabilities: [0.04463592 0.24887249 0.14367177 0.40178937 0.1610306 ]
# ----------------------------------------
# Sample 53:
# Observation: [0.   1.   0.   0.   0.   0.   0.05 0.1 ]
# Predicted action: 3
# Probabilities: [0.04432094 0.2489629  0.14308928 0.4028479  0.16077901]
# ----------------------------------------
# Sample 54:
# Observation: [0.   1.   0.   0.   0.   0.   0.17 0.19]
# Predicted action: 3
# Probabilities: [0.04491256 0.25316295 0.14511904 0.39524224 0.16156325]
# ----------------------------------------
# Sample 55:
# Observation: [0.   1.   0.   0.   0.   0.   0.22 0.03]
# Predicted action: 3
# Probabilities: [0.04552739 0.25242242 0.14613248 0.3939131  0.16200465]
# ----------------------------------------
# Sample 56:
# Observation: [1.   0.   0.   0.   0.   0.   0.11 0.15]
# Predicted action: 3
# Probabilities: [0.02532208 0.05887315 0.14191858 0.66263235 0.11125392]
# ----------------------------------------
# Sample 57:
# Observation: [0.   1.   0.   0.   0.   0.   0.11 0.19]
# Predicted action: 3
# Probabilities: [0.04454085 0.2516142  0.14407793 0.39861295 0.16115408]
# ----------------------------------------
# Sample 58:
# Observation: [1.   0.   0.   0.   0.   0.   0.21 0.14]
# Predicted action: 3
# Probabilities: [0.02566958 0.05963562 0.1441619  0.6584183  0.11211461]
# ----------------------------------------
# Sample 59:
# Observation: [0.   1.   0.   0.   0.   0.   0.02 0.2 ]
# Predicted action: 3
# Probabilities: [0.0440468  0.24939534 0.14258777 0.40337873 0.16059141]
# ----------------------------------------
# Sample 60:
# Observation: [1. 1. 0. 0. 0. 0. 0. 0.]
# Predicted action: 3
# Probabilities: [0.00929189 0.06831738 0.09039079 0.7487631  0.08323681]
# ----------------------------------------
# Sample 61:
# Observation: [1.   0.   0.   0.   0.   0.   0.15 0.05]
# Predicted action: 3
# Probabilities: [0.0255744  0.05883431 0.14284438 0.66118497 0.11156191]
# ----------------------------------------
# Sample 62:
# Observation: [1.   0.   0.   0.   0.   0.   0.08 0.04]
# Predicted action: 3
# Probabilities: [0.02537634 0.05828029 0.14133567 0.66400874 0.11099892]
# ----------------------------------------
# Sample 63:
# Observation: [0.   1.   0.   0.   0.   0.   0.06 0.09]
# Predicted action: 3
# Probabilities: [0.04439252 0.24909818 0.143263   0.4023989  0.16084749]
# ----------------------------------------
# Sample 64:
# Observation: [1.   0.   0.   0.   0.   0.   0.   0.01]
# Predicted action: 3
# Probabilities: [0.02523045 0.0576726  0.13974729 0.6668924  0.11045723]
# ----------------------------------------
# Sample 65:
# Observation: [0.   1.   0.   0.   0.   0.   0.   0.01]
# Predicted action: 3
# Probabilities: [0.04427449 0.24658374 0.1423907  0.4061872  0.16056392]
# ----------------------------------------
# Sample 66:
# Observation: [1.   0.   0.   0.   0.   0.   0.14 0.03]
# Predicted action: 3
# Probabilities: [0.02557599 0.05870103 0.14264971 0.6615839  0.11148939]
# ----------------------------------------
# Sample 67:
# Observation: [0.   1.   0.   0.   0.   0.   0.17 0.12]
# Predicted action: 3
# Probabilities: [0.04499668 0.25229242 0.14513107 0.39601195 0.1615679 ]
# ----------------------------------------
# Sample 68:
# Observation: [0.   1.   0.   0.   0.   0.   0.17 0.01]
# Predicted action: 3
# Probabilities: [0.045239   0.25090963 0.14526656 0.39691684 0.16166793]
# ----------------------------------------
# Sample 69:
# Observation: [0.   1.   0.   0.   0.   0.   0.05 0.02]
# Predicted action: 3
# Probabilities: [0.04449846 0.24798292 0.14318699 0.403479   0.1608527 ]
# ----------------------------------------
# Sample 70:
# Observation: [0.   1.   0.   0.   0.   0.   0.14 0.02]
# Predicted action: 3
# Probabilities: [0.0450186  0.25027594 0.14471924 0.39854214 0.16144414]
# ----------------------------------------
# Sample 71:
# Observation: [0.   1.   0.   0.   0.   0.   0.   0.03]
# Predicted action: 3
# Probabilities: [0.04422131 0.24682632 0.14235687 0.4060576  0.16053787]
# ----------------------------------------
# Sample 72:
# Observation: [1.   0.   0.   0.   0.   0.   0.07 0.08]
# Predicted action: 3
# Probabilities: [0.02528635 0.05832941 0.1410819  0.66439223 0.1109101 ]
# ----------------------------------------
# Sample 73:
# Observation: [1.   0.   0.   0.   0.   0.   0.12 0.06]
# Predicted action: 3
# Probabilities: [0.02546175 0.05863095 0.14217055 0.6624308  0.11130588]
# ----------------------------------------
# Sample 74:
# Observation: [1.   0.   0.   0.   0.   0.   0.05 0.01]
# Predicted action: 3
# Probabilities: [0.02535041 0.05799551 0.14075744 0.6650954  0.11080122]
# ----------------------------------------
# Sample 75:
# Observation: [1.   0.   0.   0.   0.   0.   0.06 0.  ]
# Predicted action: 3
# Probabilities: [0.02539654 0.05804038 0.14098395 0.66469353 0.11088558]
# ----------------------------------------
# Sample 76:
# Observation: [1.   0.   0.   0.   0.   0.   0.11 0.09]
# Predicted action: 3
# Probabilities: [0.0253877  0.05865069 0.14192775 0.66281277 0.11122116]
# ----------------------------------------
# Sample 77:
# Observation: [0.   1.   0.   0.   0.   0.   0.05 0.13]
# Predicted action: 3
# Probabilities: [0.04427284 0.24932866 0.14307266 0.40255848 0.16076727]
# ----------------------------------------
# Sample 78:
# Observation: [0.   1.   0.   0.   0.   0.   0.   0.07]
# Predicted action: 3
# Probabilities: [0.04412842 0.2473109  0.14230388 0.40575936 0.16049749]
# ----------------------------------------
# Sample 79:
# Observation: [1.   0.   0.   0.   0.   0.   0.03 0.06]
# Predicted action: 3
# Probabilities: [0.02521269 0.05799754 0.14027461 0.6658903  0.11062486]
# ----------------------------------------
# Sample 80:
# Observation: [1. 1. 0. 0. 0. 0. 0. 0.]
# Predicted action: 3
# Probabilities: [0.00929189 0.06831738 0.09039079 0.7487631  0.08323681]
# ----------------------------------------
# Sample 81:
# Observation: [1.   0.   0.   0.   0.   0.   0.05 0.  ]
# Predicted action: 3
# Probabilities: [0.02537031 0.05797225 0.1407768  0.66506803 0.11081261]
# ----------------------------------------
# Sample 82:
# Observation: [1.   0.   0.   0.   0.   0.   0.01 0.  ]
# Predicted action: 3
# Probabilities: [0.02527281 0.05771145 0.13996531 0.6665158  0.11053458]
# ----------------------------------------
# Sample 83:
# Observation: [0.   1.   0.   0.   0.   0.   0.   0.02]
# Predicted action: 3
# Probabilities: [0.04424735 0.24670503 0.14237316 0.40612403 0.16055039]
# ----------------------------------------
# Sample 84:
# Observation: [1.   0.   0.   0.   0.   0.   0.   0.07]
# Predicted action: 3
# Probabilities: [0.02512788 0.05783831 0.13966312 0.6669503  0.11042035]
# ----------------------------------------
# Sample 85:
# Observation: [0.   1.   0.   0.   0.   0.   0.01 0.05]
# Predicted action: 3
# Probabilities: [0.04422065 0.24732523 0.1424884  0.4053911  0.1605746 ]
# ----------------------------------------
# Sample 86:
# Observation: [1.   0.   0.   0.   0.   0.   0.01 0.01]
# Predicted action: 3
# Probabilities: [0.02525296 0.05773482 0.13994586 0.6665431  0.11052325]
# ----------------------------------------
# Sample 87:
# Observation: [0.   1.   0.   0.   0.   0.   0.01 0.06]
# Predicted action: 3
# Probabilities: [0.04419798 0.24744663 0.14247574 0.4053147  0.16056499]
# ----------------------------------------
# Sample 88:
# Observation: [0.   1.   0.   0.   0.   0.   0.13 0.01]
# Predicted action: 3
# Probabilities: [0.04498396 0.24989687 0.14456281 0.3991672  0.16138922]
# ----------------------------------------
# Sample 89:
# Observation: [0.   1.   0.   0.   0.   0.   0.02 0.13]
# Predicted action: 3
# Probabilities: [0.04411959 0.2485526  0.14258255 0.40416104 0.16058427]
# ----------------------------------------
# Sample 90:
# Observation: [0.   1.   0.   0.   0.   0.   0.05 0.01]
# Predicted action: 3
# Probabilities: [0.0445257  0.24786004 0.14320463 0.40354338 0.16086625]
# ----------------------------------------
# Sample 91:
# Observation: [0.   1.   0.   0.   0.   0.   0.01 0.01]
# Predicted action: 3
# Probabilities: [0.04432257 0.246839   0.14255126 0.40566435 0.1606228 ]
# ----------------------------------------
# Sample 92:
# Observation: [0.   1.   0.   0.   0.   0.   0.01 0.05]
# Predicted action: 3
# Probabilities: [0.04422065 0.24732523 0.1424884  0.4053911  0.1605746 ]
# ----------------------------------------
# Sample 93:
# Observation: [0.   1.   0.   0.   0.   0.   0.06 0.11]
# Predicted action: 3
# Probabilities: [0.04435706 0.24934293 0.14324814 0.40221515 0.1608367 ]
# ----------------------------------------
# Sample 94:
# Observation: [1.   0.   0.   0.   0.   0.   0.01 0.04]
# Predicted action: 3
# Probabilities: [0.02519813 0.0578122  0.13989688 0.66659474 0.11049811]
# ----------------------------------------
# Sample 95:
# Observation: [0.   1.   0.   0.   0.   0.   0.03 0.04]
# Predicted action: 3
# Probabilities: [0.04434373 0.24771616 0.14282662 0.40440813 0.1607053 ]
# ----------------------------------------
# Sample 96:
# Observation: [0.   1.   0.   0.   0.   0.   0.06 0.11]
# Predicted action: 3
# Probabilities: [0.04435706 0.24934293 0.14324814 0.40221515 0.1608367 ]
# ----------------------------------------
# Sample 97:
# Observation: [1.   0.   0.   0.   0.   0.   0.01 0.1 ]
# Predicted action: 3
# Probabilities: [0.02510969 0.05799945 0.13984099 0.66656196 0.11048789]
# ----------------------------------------
# Sample 98:
# Observation: [1.   0.   0.   0.   0.   0.   0.04 0.07]
# Predicted action: 3
# Probabilities: [0.02522224 0.05809374 0.14046846 0.6655231  0.1106925 ]
# ----------------------------------------
# Sample 99:
# Observation: [0.   1.   0.   0.   0.   0.   0.11 0.02]
# Predicted action: 3
# Probabilities: [0.04483551 0.24951339 0.14419913 0.4002116  0.16124043]
# ----------------------------------------
# Sample 100:
# Observation: [1. 1. 0. 0. 0. 0. 0. 0.]
# Predicted action: 3
# Probabilities: [0.00929189 0.06831738 0.09039079 0.7487631  0.08323681]
# ----------------------------------------
# Action counts: {0: 0, 1: 0, 2: 0, 3: 100, 4: 0}
