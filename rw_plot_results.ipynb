# %%
from rw_heuristics import random_policy, spt_policy, fifo_policy
from rw_heuristics import hrrn_policy, longest_queue_policy, shortest_queue_policy
from rw_heuristics import least_flexible_resource_policy, most_flexible_resource_policy
from rw_heuristics import least_flexible_activity_policy, most_flexible_activity_policy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import matplotlib.patches as mpatches
import os

problem_names = ['bpi2012', 'bpi2017', 'microsoft', 'production', 'consulta']
heuristics = [spt_policy, fifo_policy,
              hrrn_policy, longest_queue_policy, shortest_queue_policy,
              least_flexible_resource_policy, most_flexible_resource_policy,
              least_flexible_activity_policy, most_flexible_activity_policy]

# Create a mapping for more readable labels
heuristic_labels = {
    'spt_policy': 'SPT',
    'fifo_policy': 'FIFO',
    'random_policy': 'Random',
    'hrrn_policy': 'HRRN',
    'longest_queue_policy': 'LQF',
    'shortest_queue_policy': 'SQF',
    'least_flexible_resource_policy': 'LFRF',
    'most_flexible_resource_policy': 'MFRF',
    'least_flexible_activity_policy': 'LFAF',
    'most_flexible_activity_policy': 'MFAF'
}

# Iterate over each problem name
for problem_name in problem_names:
    data = []
    labels = []
    
    # Read data for each heuristic
    for heuristic in heuristics:
        heuristic_name = heuristic.__name__
        try:
            df = pd.read_csv(f'results/{problem_name}/{problem_name}_{heuristic_name}.txt')
            cycle_times = df['cycle_time']
            data.append(cycle_times)
            labels.append(heuristic_name)
        except FileNotFoundError:
            print(f"File not found: results/{problem_name}/{problem_name}_{heuristic_name}.txt")
    
    if not data:  # Skip if no data found
        print(f"No data found for {problem_name}")
        continue
        
    # Create a box plot
    plt.figure(figsize=(12, 7))
    box = plt.boxplot(data, labels=[heuristic_labels.get(l, l) for l in labels], 
                     showmeans=True, patch_artist=True)
    
    # Calculate statistics
    mean_values = [np.mean(d) for d in data]
    std_values = [np.std(d) for d in data]
    
    # Find the best heuristic (lowest mean cycle time)
    best_policy_index = np.argmin(mean_values)
    best_policy = labels[best_policy_index]
    best_policy_data = data[best_policy_index]
    
    # Print mean and standard deviation for each policy
    print(f"\nMean and std for {problem_name}:")
    for label, mean, std in zip(labels, mean_values, std_values):
        print(f"{label}: {mean:.1f} ({std:.1f})")
    
    # Perform t-test between the best policy and all other policies
    p_values = []
    significance = []
    
    for i, (policy, policy_data) in enumerate(zip(labels, data)):
        if i == best_policy_index:
            p_values.append(1.0)  # Same distribution, p-value = 1
            significance.append(False)
        else:
            # Independent two-sample t-test
            stat, p = stats.ttest_ind(best_policy_data, policy_data, equal_var=True)
            p_values.append(p)
            significance.append(p < 0.05)  # Consider p < 0.05 as significant
    
    # Color the boxes based on significance
    for i, (patch, sig) in enumerate(zip(box['boxes'], significance)):
        if i == best_policy_index:
            patch.set_facecolor('lightgreen')  # Best policy in green
        elif sig:
            patch.set_facecolor('lightcoral')  # Significantly different in red
        else:
            patch.set_facecolor('lightblue')  # Not significantly different in blue
    
    # Add a legend
    best_patch = mpatches.Patch(color='lightgreen', label='Best policy')
    sig_patch = mpatches.Patch(color='lightcoral', label='Significantly different (p<0.05)')
    nonsig_patch = mpatches.Patch(color='lightblue', label='Not significantly different')
    plt.legend(handles=[best_patch, sig_patch, nonsig_patch], loc='upper right')
    
    # Add p-values above the boxes
    y_max = max([max(d) for d in data if len(d) > 0])
    y_min = min([min(d) for d in data if len(d) > 0])
    y_range = y_max - y_min
    for i, p in enumerate(p_values):
        if i != best_policy_index:
            plt.text(i+1, y_max + y_range * 0.05, f'p={p:.3f}', 
                     horizontalalignment='center', size='small')
    
    plt.title(f'Cycle Times for {problem_name}\nBest policy: {heuristic_labels.get(best_policy, best_policy)}')
    plt.ylabel('Cycle Time')
    plt.xlabel('Policy')
    plt.xticks(rotation=45)
    plt.tight_layout()
    
    # Save the plot
    os.makedirs('figures', exist_ok=True)
    plt.savefig(f'figures/{problem_name}_boxplot.png')
    plt.show()
    
    # Print detailed test results
    print(f"\nSignificance test results for {problem_name}:")
    print(f"Best policy: {best_policy} (Mean: {mean_values[best_policy_index]:.2f})")
    print("-" * 50)
    for i, policy in enumerate(labels):
        if i != best_policy_index:
            print(f"{policy} vs {best_policy}: p-value = {p_values[i]:.5f} {'(significant)' if significance[i] else '(not significant)'}")
    print("\n")
# Out:
# C:\Users\jeroe\AppData\Local\Temp\ipykernel_351832\1573006291.py:54: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = plt.boxplot(data, labels=[heuristic_labels.get(l, l) for l in labels],
# Mean and std for bpi2012:
# spt_policy: 8.3 (3.2)
# fifo_policy: 55.0 (28.9)
# hrrn_policy: 10.1 (3.2)
# longest_queue_policy: 79.6 (41.6)
# shortest_queue_policy: 49.5 (24.6)
# least_flexible_resource_policy: 9.4 (3.0)
# most_flexible_resource_policy: 8.7 (3.1)
# least_flexible_activity_policy: 41.4 (22.2)
# most_flexible_activity_policy: 52.0 (27.4)
# Significance test results for bpi2012:
# Best policy: spt_policy (Mean: 8.25)
# --------------------------------------------------
# fifo_policy vs spt_policy: p-value = 0.00000 (significant)
# hrrn_policy vs spt_policy: p-value = 0.00000 (significant)
# longest_queue_policy vs spt_policy: p-value = 0.00000 (significant)
# shortest_queue_policy vs spt_policy: p-value = 0.00000 (significant)
# least_flexible_resource_policy vs spt_policy: p-value = 0.00001 (significant)
# most_flexible_resource_policy vs spt_policy: p-value = 0.10145 (not significant)
# least_flexible_activity_policy vs spt_policy: p-value = 0.00000 (significant)
# most_flexible_activity_policy vs spt_policy: p-value = 0.00000 (significant)
#
#
#
# Mean and std for bpi2017:
# spt_policy: 8.9 (1.5)
# fifo_policy: 9.7 (1.7)
# hrrn_policy: 8.3 (1.1)
# longest_queue_policy: 11.6 (2.3)
# shortest_queue_policy: 9.8 (1.7)
# least_flexible_resource_policy: 10.2 (1.8)
# most_flexible_resource_policy: 9.0 (1.6)
# least_flexible_activity_policy: 11.6 (1.9)
# most_flexible_activity_policy: 9.2 (1.7)
# C:\Users\jeroe\AppData\Local\Temp\ipykernel_351832\1573006291.py:54: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = plt.boxplot(data, labels=[heuristic_labels.get(l, l) for l in labels],
# Significance test results for bpi2017:
# Best policy: hrrn_policy (Mean: 8.31)
# --------------------------------------------------
# spt_policy vs hrrn_policy: p-value = 0.00000 (significant)
# fifo_policy vs hrrn_policy: p-value = 0.00000 (significant)
# longest_queue_policy vs hrrn_policy: p-value = 0.00000 (significant)
# shortest_queue_policy vs hrrn_policy: p-value = 0.00000 (significant)
# least_flexible_resource_policy vs hrrn_policy: p-value = 0.00000 (significant)
# most_flexible_resource_policy vs hrrn_policy: p-value = 0.00000 (significant)
# least_flexible_activity_policy vs hrrn_policy: p-value = 0.00000 (significant)
# most_flexible_activity_policy vs hrrn_policy: p-value = 0.00000 (significant)
#
#
#
# Mean and std for microsoft:
# spt_policy: 271.7 (99.5)
# fifo_policy: 170.8 (78.9)
# hrrn_policy: 159.1 (48.2)
# longest_queue_policy: 250.0 (127.4)
# shortest_queue_policy: 185.7 (100.1)
# least_flexible_resource_policy: 358.8 (108.0)
# most_flexible_resource_policy: 397.9 (113.0)
# least_flexible_activity_policy: 197.3 (83.9)
# most_flexible_activity_policy: 310.0 (92.1)
# C:\Users\jeroe\AppData\Local\Temp\ipykernel_351832\1573006291.py:54: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = plt.boxplot(data, labels=[heuristic_labels.get(l, l) for l in labels],
# Significance test results for microsoft:
# Best policy: hrrn_policy (Mean: 159.10)
# --------------------------------------------------
# spt_policy vs hrrn_policy: p-value = 0.00000 (significant)
# fifo_policy vs hrrn_policy: p-value = 0.02918 (significant)
# longest_queue_policy vs hrrn_policy: p-value = 0.00000 (significant)
# shortest_queue_policy vs hrrn_policy: p-value = 0.00004 (significant)
# least_flexible_resource_policy vs hrrn_policy: p-value = 0.00000 (significant)
# most_flexible_resource_policy vs hrrn_policy: p-value = 0.00000 (significant)
# least_flexible_activity_policy vs hrrn_policy: p-value = 0.00000 (significant)
# most_flexible_activity_policy vs hrrn_policy: p-value = 0.00000 (significant)
#
#
#
# Mean and std for production:
# spt_policy: 145.7 (27.3)
# fifo_policy: 266.2 (97.1)
# hrrn_policy: 162.1 (18.9)
# longest_queue_policy: 172.5 (33.5)
# shortest_queue_policy: 563.4 (222.1)
# least_flexible_resource_policy: 172.4 (33.1)
# most_flexible_resource_policy: 169.2 (31.0)
# least_flexible_activity_policy: 172.0 (33.9)
# most_flexible_activity_policy: 452.1 (151.5)
# C:\Users\jeroe\AppData\Local\Temp\ipykernel_351832\1573006291.py:54: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = plt.boxplot(data, labels=[heuristic_labels.get(l, l) for l in labels],
# C:\Users\jeroe\AppData\Local\Temp\ipykernel_351832\1573006291.py:54: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = plt.boxplot(data, labels=[heuristic_labels.get(l, l) for l in labels],
# Significance test results for production:
# Best policy: spt_policy (Mean: 145.71)
# --------------------------------------------------
# fifo_policy vs spt_policy: p-value = 0.00000 (significant)
# hrrn_policy vs spt_policy: p-value = 0.00000 (significant)
# longest_queue_policy vs spt_policy: p-value = 0.00000 (significant)
# shortest_queue_policy vs spt_policy: p-value = 0.00000 (significant)
# least_flexible_resource_policy vs spt_policy: p-value = 0.00000 (significant)
# most_flexible_resource_policy vs spt_policy: p-value = 0.00000 (significant)
# least_flexible_activity_policy vs spt_policy: p-value = 0.00000 (significant)
# most_flexible_activity_policy vs spt_policy: p-value = 0.00000 (significant)
#
#
#
# Mean and std for consulta:
# spt_policy: 91.8 (21.8)
# fifo_policy: 349.7 (139.4)
# hrrn_policy: 66.7 (5.5)
# longest_queue_policy: 170.3 (74.3)
# shortest_queue_policy: 318.0 (127.3)
# least_flexible_resource_policy: 115.8 (30.3)
# most_flexible_resource_policy: 110.6 (31.1)
# least_flexible_activity_policy: 346.8 (135.4)
# most_flexible_activity_policy: 114.4 (29.4)
# Significance test results for consulta:
# Best policy: hrrn_policy (Mean: 66.72)
# --------------------------------------------------
# spt_policy vs hrrn_policy: p-value = 0.00000 (significant)
# fifo_policy vs hrrn_policy: p-value = 0.00000 (significant)
# longest_queue_policy vs hrrn_policy: p-value = 0.00000 (significant)
# shortest_queue_policy vs hrrn_policy: p-value = 0.00000 (significant)
# least_flexible_resource_policy vs hrrn_policy: p-value = 0.00000 (significant)
# most_flexible_resource_policy vs hrrn_policy: p-value = 0.00000 (significant)
# least_flexible_activity_policy vs hrrn_policy: p-value = 0.00000 (significant)
# most_flexible_activity_policy vs hrrn_policy: p-value = 0.00000 (significant)

# %%
# Add this code to create a LaTeX table
print("\\begin{table}[htbp]")
print("\\centering")
print("\\caption{Mean cycle times and standard deviations for different policies across problems}")
print("\\label{tab:policy_comparison}")
print("\\resizebox{\\textwidth}{!}{%")  # Make table fit page width

# Start the tabular environment with the correct number of columns
# First column for problem names + one column per heuristic
headers = ["Event log"] + [heuristic_labels.get(h.__name__, h.__name__) for h in heuristics]
num_cols = len(headers)
print("\\begin{tabular}{l" + "r" * (num_cols-1) + "}")
print("\\toprule")

# Print the header row
print(" & ".join(headers) + " \\\\")
print("\\midrule")

# Store all results to create the table
all_results = {}

# Collect data for each problem
for problem_name in problem_names:
    data = []
    labels = []
    
    # Read data for each heuristic
    for heuristic in heuristics:
        heuristic_name = heuristic.__name__
        try:
            df = pd.read_csv(f'results/{problem_name}/{problem_name}_{heuristic_name}.txt')
            cycle_times = df['cycle_time']
            data.append(cycle_times)
            labels.append(heuristic_name)
        except FileNotFoundError:
            data.append(np.array([]))
            labels.append(heuristic_name)
    
    if not any(len(d) > 0 for d in data):  # Skip if no data found
        continue
    
    # Calculate statistics for each policy
    mean_values = [np.mean(d) if len(d) > 0 else float('nan') for d in data]
    std_values = [np.std(d) if len(d) > 0 else float('nan') for d in data]
    
    # Find the best policy (lowest mean cycle time)
    valid_means = [m for m in mean_values if not np.isnan(m)]
    if valid_means:
        best_value = min(valid_means)
        best_indices = [i for i, m in enumerate(mean_values) if m == best_value]
    else:
        best_indices = []
    
    # Store results
    all_results[problem_name] = {
        'means': mean_values,
        'stds': std_values,
        'best_indices': best_indices
    }
    
    problem_names_formatted = {'bpi2012': 'BPI2012W',
                               'bpi2017': 'BPI2017W',
                               'microsoft': 'MC',
                               'production': 'PR',
                               'consulta': 'CDM'}

    # Create the row for this problem
    row_values = [problem_names_formatted[problem_name]]
    for i, (mean, std) in enumerate(zip(mean_values, std_values)):
        if np.isnan(mean):
            cell = "—"  # Em dash for missing data
        else:
            # Bold the best value
            if i in best_indices:
                cell = f"\\textbf{{{mean:.1f}}}"
            else:
                cell = f"{mean:.1f}"
        row_values.append(cell)
    
    # Print the row
    print(" & ".join(row_values) + " \\\\")

print("\\bottomrule")
print("\\end{tabular}}")
print("\\caption*{Note: Values represent mean cycle time (standard deviation). Best policies for each problem are highlighted in bold.}")
print("\\end{table}")
# Out:
# \begin{table}[htbp]
# \centering
# \caption{Mean cycle times and standard deviations for different policies across problems}
# \label{tab:policy_comparison}
# \resizebox{\textwidth}{!}{%
# \begin{tabular}{lrrrrrrrrr}
# \toprule
# Event log & SPT & FIFO & HRRN & LQF & SQF & LFRF & MFRF & LFAF & MFAF \\
# \midrule
# BPI2012W & \textbf{8.3} & 55.0 & 10.1 & 79.6 & 49.5 & 9.4 & 8.7 & 41.4 & 52.0 \\
# BPI2017W & 8.9 & 9.7 & \textbf{8.3} & 11.6 & 9.8 & 10.2 & 9.0 & 11.6 & 9.2 \\
# MC & 271.7 & 170.8 & \textbf{159.1} & 250.0 & 185.7 & 358.8 & 397.9 & 197.3 & 310.0 \\
# PR & \textbf{145.7} & 266.2 & 162.1 & 172.5 & 563.4 & 172.4 & 169.2 & 172.0 & 452.1 \\
# CDM & 91.8 & 349.7 & \textbf{66.7} & 170.3 & 318.0 & 115.8 & 110.6 & 346.8 & 114.4 \\
# \bottomrule
# \end{tabular}}
# \caption*{Note: Values represent mean cycle time (standard deviation). Best policies for each problem are highlighted in bold.}
# \end{table}
